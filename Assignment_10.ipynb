# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.probability import FreqDist
import matplotlib.pyplot as plt
import nltk

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')

text = """Cricket is one of my favorite sports to watch.I have acquired this love for sports from my father.We watch the IPL together every year.It's competitive and that's what makes it fun
"""
clean_text = re.sub(r"[^\w\s']", "", text.lower())
words_nltk = word_tokenize(clean_text)
stop_words = set(stopwords.words('english'))
filtered_words = [w for w in words_nltk if w not in stop_words and len(w) > 1]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
fdist = FreqDist(filtered_words)
print("Top 10 Terms:", fdist.most_common(10))
fdist.plot(10)
plt.show()
# Out:
# Top 10 Terms: [('sports', 2), ("'s", 2), ('cricket', 1), ('one', 1), ('favorite', 1), ('watchi', 1), ('acquired', 1), ('love', 1), ('fatherwe', 1), ('watch', 1)]

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
#Q2
alphabets=re.findall(r'\b[a-zA-Z]+\b',text)
stop_words= set(stopwords.words('english'))
filtered_words=[w for w in words_nltk if w.lower() not in stop_words]
print("filtered words:",filtered_words)
ps=PorterStemmer()
stemmed= [ps.stem(word) for word in filtered_words]
print("stemmed word:",stemmed)
# Out:
# filtered words: ['cricket', 'one', 'favorite', 'sports', 'watchi', 'acquired', 'love', 'sports', 'fatherwe', 'watch', 'ipl', 'together', 'every', 'yearit', "'s", 'competitive', "'s", 'makes', 'fun']
# stemmed word: ['cricket', 'one', 'favorit', 'sport', 'watchi', 'acquir', 'love', 'sport', 'fatherw', 'watch', 'ipl', 'togeth', 'everi', 'yearit', "'s", 'competit', "'s", 'make', 'fun']

# %%
lm=WordNetLemmatizer()
lemmatized=[lm.lemmatize(word) for word in filtered_words]
print("lemmatized word:",lemmatized)
comparison = list(zip(filtered_words, stemmed, lemmatized))
for original, stem, lemma in comparison:
    print(f"{original:8} → Stem: {stem:8} | Lemma: {lemma}")
# Out:
# lemmatized word: ['cricket', 'one', 'favorite', 'sport', 'watchi', 'acquired', 'love', 'sport', 'fatherwe', 'watch', 'ipl', 'together', 'every', 'yearit', "'s", 'competitive', "'s", 'make', 'fun']
# cricket  → Stem: cricket  | Lemma: cricket
# one      → Stem: one      | Lemma: one
# favorite → Stem: favorit  | Lemma: favorite
# sports   → Stem: sport    | Lemma: sport
# watchi   → Stem: watchi   | Lemma: watchi
# acquired → Stem: acquir   | Lemma: acquired
# love     → Stem: love     | Lemma: love
# sports   → Stem: sport    | Lemma: sport
# fatherwe → Stem: fatherw  | Lemma: fatherwe
# watch    → Stem: watch    | Lemma: watch
# ipl      → Stem: ipl      | Lemma: ipl
# together → Stem: togeth   | Lemma: together
# every    → Stem: everi    | Lemma: every
# yearit   → Stem: yearit   | Lemma: yearit
# 's       → Stem: 's       | Lemma: 's
# competitive → Stem: competit | Lemma: competitive
# 's       → Stem: 's       | Lemma: 's
# makes    → Stem: make     | Lemma: make
# fun      → Stem: fun      | Lemma: fun

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

texts = [
    "Maths is a very interesting subject.",
    "The odds of winning thisare minimal.",
    "There are many branches in engineering"
]

cv = CountVectorizer()
bow = cv.fit_transform(texts)

# %%
tfidf = TfidfVectorizer().fit(texts)
tfidf_matrix = tfidf.transform(texts)
feature_names = tfidf.get_feature_names_out()

for i, doc in enumerate(texts):
    doc_scores = tfidf_matrix[i].toarray()[0]
    word_scores = list(zip(feature_names, doc_scores))
    top_keywords = sorted(word_scores, key=lambda x: x[1], reverse=True)[:3]
    print(f"Text {i+1} top keywords:", [word for word,score in top_keywords])
# Out:
# Text 1 top keywords: ['interesting', 'is', 'maths']
# Text 2 top keywords: ['minimal', 'odds', 'of']
# Text 3 top keywords: ['are', 'branches', 'engineering']

# %%
#Q4
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.tokenize import word_tokenize

ai_text = "AI learns from data patterns using neural networks. It enables predictive analytics. Deep learning improves image recognition."
blockchain_text = "Blockchain creates tamper-proof transaction records. It uses decentralized ledgers. Cryptography secures all blockchain data."

def jaccard_sim(a, b):
    a_set = set(word_tokenize(a.lower()))
    b_set = set(word_tokenize(b.lower()))
    return len(a_set & b_set) / len(a_set | b_set)

tfidf = TfidfVectorizer().fit_transform([ai_text, blockchain_text])

print(f"Jaccard Similarity: {jaccard_sim(ai_text, blockchain_text):.2f}")
print(f"Cosine Similarity: {cosine_similarity(tfidf[0:1], tfidf[1:2])[0][0]:.2f}")
# Out:
# Jaccard Similarity: 0.10
# Cosine Similarity: 0.06

# %%
#Q5
review = """This hairdryer is fantastic! It dries my hair quickly without excessive heat damage.
The ionic technology leaves my hair smooth and shiny. However, it's a bit noisy at the highest setting.
Overall, I'm very satisfied with this purchase."""
from textblob import TextBlob
from wordcloud import WordCloud
import matplotlib.pyplot as plt

blob = TextBlob(review)
polarity = blob.sentiment.polarity
sentiment = "Positive" if polarity > 0 else "Negative" if polarity < 0 else "Neutral"

wc = WordCloud(width=400, height=300).generate(review)
plt.imshow(wc)
plt.axis("off")
plt.show()

print(f"Polarity: {polarity:.2f}")
print(f"Sentiment: {sentiment}")
# Out:
# Polarity: 0.27
# Sentiment: Positive

# %%
#q6
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.utils import to_categorical

movie_paragraph = """Inception is a mind-bending sci-fi thriller about dream infiltration.
The Dark Knight revolutionized superhero movies with its gritty realism.
Pulp Fiction's non-linear storytelling became iconic in cinema history.
Interstellar explored theoretical physics through emotional space exploration.
The Shawshank Redemption remains the highest-rated drama about hope and perseverance."""

tokenizer = Tokenizer()
tokenizer.fit_on_texts([movie_paragraph])
total_words = len(tokenizer.word_index) + 1

input_sequences = []
for line in movie_paragraph.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre')
X = input_sequences[:,:-1]
y = to_categorical(input_sequences[:,-1], num_classes=total_words)

model = Sequential()
model.add(Embedding(total_words, 64, input_length=max_sequence_len-1))
model.add(LSTM(150))
model.add(Dense(total_words, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=100, verbose=1)

def generate_text(seed_text, next_words):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = np.argmax(model.predict(token_list, verbose=0), axis=-1)
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

print(generate_text("Inception is", 5))
print(generate_text("The Shawshank", 3))
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.0145 - loss: 3.8931
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.0643 - loss: 3.8838
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1639 - loss: 3.8768
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.1390 - loss: 3.8694
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1245 - loss: 3.8614
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.1141 - loss: 3.8510
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.0996 - loss: 3.8376
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.0684 - loss: 3.8181
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.0747 - loss: 3.7930
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.0747 - loss: 3.7612
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.0747 - loss: 3.7131
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.0145 - loss: 3.6796
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.0249 - loss: 3.6410
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.0290 - loss: 3.5898
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1182 - loss: 3.5514
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2034 - loss: 3.5027
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.2283 - loss: 3.4465
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.2074 - loss: 3.3656
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1431 - loss: 3.3066
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1680 - loss: 3.1495
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1431 - loss: 3.0930
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2115 - loss: 2.9907
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2428 - loss: 2.8656
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.2572 - loss: 2.7441
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3424 - loss: 2.6464
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3216 - loss: 2.5550
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3175 - loss: 2.4266
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.3673 - loss: 2.3069
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3963 - loss: 2.2742
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5186 - loss: 2.1517
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5353 - loss: 2.0343
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6245 - loss: 1.9393
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5394 - loss: 1.8928
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6495 - loss: 1.8132
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5788 - loss: 1.8358
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5829 - loss: 1.7334
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7034 - loss: 1.5837
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7219 - loss: 1.5607
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7885 - loss: 1.4833
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6784 - loss: 1.4610
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7677 - loss: 1.3791
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8922 - loss: 1.3488
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8111 - loss: 1.3594
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8071 - loss: 1.2681
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8071 - loss: 1.2483
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8714 - loss: 1.1877
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8963 - loss: 1.1535
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8320 - loss: 1.1558
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8610 - loss: 1.1462
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7862 - loss: 1.1083
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8424 - loss: 1.0488
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8465 - loss: 1.0526
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8714 - loss: 0.9493
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8963 - loss: 0.9807
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8216 - loss: 0.9843
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8505 - loss: 0.9614
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8963 - loss: 0.9069
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8361 - loss: 0.9226
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8714 - loss: 0.8342
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9316 - loss: 0.8480
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8755 - loss: 0.8595
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9004 - loss: 0.8503
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9108 - loss: 0.8321
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9461 - loss: 0.7854
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9357 - loss: 0.7682
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9004 - loss: 0.7514
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9357 - loss: 0.7599
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9004 - loss: 0.7543
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9316 - loss: 0.6740
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9253 - loss: 0.7508
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9067 - loss: 0.6879
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9502 - loss: 0.7073
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9606 - loss: 0.6764
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9461 - loss: 0.6297
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9461 - loss: 0.6336
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9606 - loss: 0.6175
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9751 - loss: 0.6418
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9751 - loss: 0.6391
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9606 - loss: 0.5947
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9502 - loss: 0.5898
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9606 - loss: 0.5725
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9606 - loss: 0.5744
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9606 - loss: 0.5464
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9502 - loss: 0.5232
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9855 - loss: 0.5297
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9502 - loss: 0.5528
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9855 - loss: 0.5196
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9751 - loss: 0.5321
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9751 - loss: 0.5095
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9751 - loss: 0.4965
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9751 - loss: 0.5053
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9855 - loss: 0.4673
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9855 - loss: 0.4568
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9751 - loss: 0.4524
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9855 - loss: 0.4423
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9751 - loss: 0.4887
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9751 - loss: 0.4746
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9606 - loss: 0.4151
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9751 - loss: 0.4103
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9855 - loss: 0.4028
# Inception is a mind bending sci fi
# The Shawshank redemption remains the
